# %% [markdown]
# # air and climate

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt  # visualization
import seaborn as sns # visualization
# %matplotlib inline
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns        module    <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>

# %%
emission_df = pd.read_csv("AIR_EMISSIONS_05122019095014921.csv")
GDP_CO2_df = pd.read_csv("GDP_CO2.csv")
productGDP_df = pd.read_csv("gross_domestic_product.csv")
multifactor_PG_df = pd.read_csv("multifactor_PG.csv")
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
emission_df.Variable.value_counts()
# Out:
# Total emissions per capita                          5642
# Total man-made emissions                            5642
# Total Stationary Sources                            5640
# Total emissions per unit of GDP, Kg per 1000 USD    5638
# Total Mobile Sources                                5530
# Total emissions, Index 2000 = 100                   5507
# Power stations                                      5427
# Road Transport                                      5391
# Combustion                                          5385
# Industrial combustion                               5385
# Other Mobile Sources                                5383
# Other combustion                                    5379
# Industrial processes and product use                5368
# Total emissions, Index 1990 = 100                   5095
# Agriculture                                         5080
# Waste                                               4922
# Miscellaneous                                       4400
# Name: Variable, dtype: int64

# %%
emission =emission_df.loc[(emission_df.Variable == 'Total man-made emissions')&(emission_df.Pollutant == 'Carbon Monoxide')]
emission.drop(['Year', 'COU','Unit','Reference Period Code','Reference Period','Flag Codes','Flags'], axis=1,inplace = True) #not needed columns.
emission
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Country POL        Pollutant  VAR                  Variable   YEA  \
# 756    Australia  CO  Carbon Monoxide  TOT  Total man-made emissions  1990
# 757    Australia  CO  Carbon Monoxide  TOT  Total man-made emissions  1991
# 758    Australia  CO  Carbon Monoxide  TOT  Total man-made emissions  1992
# 759    Australia  CO  Carbon Monoxide  TOT  Total man-made emissions  1993
# 760    Australia  CO  Carbon Monoxide  TOT  Total man-made emissions  1994
# ...          ...  ..              ...  ...                       ...   ...
# 90203  Lithuania  CO  Carbon Monoxide  TOT  Total man-made emissions  2013
# 90204  Lithuania  CO  Carbon Monoxide  TOT  Total man-made emissions  2014
# 90205  Lithuania  CO  Carbon Monoxide  TOT  Total man-made emissions  2015
# 90206  Lithuania  CO  Carbon Monoxide  TOT  Total man-made emissions  2016
# 90207  Lithuania  CO  Carbon Monoxide  TOT  Total man-made emissions  2017
#
#       Unit Code  PowerCode Code  PowerCode     Value
# 756       TONNE               3  Thousands  5728.460
# 757       TONNE               3  Thousands  5747.308
# 758       TONNE               3  Thousands  5896.593
# 759       TONNE               3  Thousands  6120.709
# 760       TONNE               3  Thousands  6262.916
# ...         ...             ...        ...       ...
# 90203     TONNE               3  Thousands   159.241
# 90204     TONNE               3  Thousands   151.081
# 90205     TONNE               3  Thousands   144.406
# 90206     TONNE               3  Thousands   142.717
# 90207     TONNE               3  Thousands   139.197
#
# [1012 rows x 10 columns]

# %%
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'G7'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'G20'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD - Europe'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD - Total'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD America'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'World'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'ASEAN'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Latin America and Caribbean'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Middle East and North Africa'].index , inplace = True)
multifactor = multifactor_PG_df.loc[multifactor_PG_df['VAR'] == 'EAMFP_EAMFPG']
multifactor.shape
# Out:
# (744, 15)

# %%
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'G7'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'G20'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD - Europe'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD - Total'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD America'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'World'].index , inplace = True)
GDP_CO2 =GDP_CO2_df.loc[(GDP_CO2_df.VAR == 'CO2_PBPROD')]
GDP_CO2.shape
# Out:
# (2674, 15)

# %%
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'G7'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD - Total'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'G20'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD - Europe'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD America'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'World'].index , inplace = True)
productGDP=productGDP_df.loc[(productGDP_df['SUBJECT'] == 'T_GDP')&(productGDP_df.Unit == 'US Dollar')& (productGDP_df.MEASURE =='VPVOB')]
productGDP.shape
# Out:
# (1813, 17)

# %%
CO2_col = GDP_CO2[['Country','YEA','PowerCode','Unit','Value','Variable',]]
productGDP_col = productGDP[['Country','TIME','Unit','Value','PowerCode','Subject']]
multifactor_col = multifactor[['Country','YEA','Unit','Value','PowerCode','Variable']]

# %%
productGDP_col.rename(columns ={'TIME' : 'YEA'}, inplace=True )
GDPandCO2 = pd.merge(productGDP_col, CO2_col, on=['Country','YEA'], how='inner')
test = pd.merge(GDPandCO2, multifactor_col, on=['Country','YEA'], how='inner')
test.rename(columns ={'Value_x' : 'GDP'}, inplace=True )
test.rename(columns ={'Value_y' : 'CO2 GDP'}, inplace=True )
test.rename(columns ={'Value' : 'multifactor'}, inplace=True )
test
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#        Country   YEA     Unit_x          GDP PowerCode_x  \
# 0    Australia  1995  US Dollar  574401.6402    Millions
# 1    Australia  2000  US Dollar  695179.4993    Millions
# 2    Australia  2001  US Dollar  722996.6281    Millions
# 3    Australia  2002  US Dollar  744585.0171    Millions
# 4    Australia  2003  US Dollar  774781.6857    Millions
# ..         ...   ...        ...          ...         ...
# 622  Lithuania  2009  US Dollar   61222.6963    Millions
# 623  Lithuania  2010  US Dollar   62226.6379    Millions
# 624  Lithuania  2011  US Dollar   65987.0750    Millions
# 625  Lithuania  2012  US Dollar   68512.3701    Millions
# 626  Lithuania  2013  US Dollar   70909.3307    Millions
#
#                                     Subject PowerCode_y  Unit_y   CO2 GDP  \
# 0    Gross Domestic Product (GDP); millions       Units  Number  2.013156
# 1    Gross Domestic Product (GDP); millions       Units  Number  2.077365
# 2    Gross Domestic Product (GDP); millions       Units  Number  2.120337
# 3    Gross Domestic Product (GDP); millions       Units  Number  2.133708
# 4    Gross Domestic Product (GDP); millions       Units  Number  2.226577
# ..                                      ...         ...     ...       ...
# 622  Gross Domestic Product (GDP); millions       Units  Number  5.367111
# 623  Gross Domestic Product (GDP); millions       Units  Number  5.052909
# 624  Gross Domestic Product (GDP); millions       Units  Number  5.725554
# 625  Gross Domestic Product (GDP); millions       Units  Number  5.941576
# 626  Gross Domestic Product (GDP); millions       Units  Number  6.523991
#
#                                             Variable_x               Unit  \
# 0    Production-based CO2 productivity, GDP per uni...  Percentage points
# 1    Production-based CO2 productivity, GDP per uni...  Percentage points
# 2    Production-based CO2 productivity, GDP per uni...  Percentage points
# 3    Production-based CO2 productivity, GDP per uni...  Percentage points
# 4    Production-based CO2 productivity, GDP per uni...  Percentage points
# ..                                                 ...                ...
# 622  Production-based CO2 productivity, GDP per uni...  Percentage points
# 623  Production-based CO2 productivity, GDP per uni...  Percentage points
# 624  Production-based CO2 productivity, GDP per uni...  Percentage points
# 625  Production-based CO2 productivity, GDP per uni...  Percentage points
# 626  Production-based CO2 productivity, GDP per uni...  Percentage points
#
#      multifactor PowerCode                                         Variable_y
# 0       2.040453     Units  Environmentally adjusted multifactor productiv...
# 1       0.962618     Units  Environmentally adjusted multifactor productiv...
# 2       3.157764     Units  Environmentally adjusted multifactor productiv...
# 3       1.390201     Units  Environmentally adjusted multifactor productiv...
# 4       2.696690     Units  Environmentally adjusted multifactor productiv...
# ..           ...       ...                                                ...
# 622    -9.279573     Units  Environmentally adjusted multifactor productiv...
# 623     6.739208     Units  Environmentally adjusted multifactor productiv...
# 624     6.462632     Units  Environmentally adjusted multifactor productiv...
# 625     2.493612     Units  Environmentally adjusted multifactor productiv...
# 626     2.900805     Units  Environmentally adjusted multifactor productiv...
#
# [627 rows x 14 columns]

# %%
test = pd.merge(test, emission, on=['Country','YEA'], how='inner')

# %%
test.drop(['PowerCode Code'], axis=1,inplace = True) #not needed columns.
test
# Out:
#        Country   YEA     Unit_x          GDP  PowerCode_x  \
# 0    Australia  1995  US Dollar  574401.6402     Millions
# 1    Australia  2000  US Dollar  695179.4993     Millions
# 2    Australia  2001  US Dollar  722996.6281     Millions
# 3    Australia  2002  US Dollar  744585.0171     Millions
# 4    Australia  2003  US Dollar  774781.6857     Millions
# ..         ...   ...        ...          ...          ...
# 507  Lithuania  2009  US Dollar   61222.6963     Millions
# 508  Lithuania  2010  US Dollar   62226.6379     Millions
# 509  Lithuania  2011  US Dollar   65987.0750     Millions
# 510  Lithuania  2012  US Dollar   68512.3701     Millions
# 511  Lithuania  2013  US Dollar   70909.3307     Millions
#
#                                     Subject PowerCode_y  Unit_y   CO2 GDP  \
# 0    Gross Domestic Product (GDP); millions       Units  Number  2.013156
# 1    Gross Domestic Product (GDP); millions       Units  Number  2.077365
# 2    Gross Domestic Product (GDP); millions       Units  Number  2.120337
# 3    Gross Domestic Product (GDP); millions       Units  Number  2.133708
# 4    Gross Domestic Product (GDP); millions       Units  Number  2.226577
# ..                                      ...         ...     ...       ...
# 507  Gross Domestic Product (GDP); millions       Units  Number  5.367111
# 508  Gross Domestic Product (GDP); millions       Units  Number  5.052909
# 509  Gross Domestic Product (GDP); millions       Units  Number  5.725554
# 510  Gross Domestic Product (GDP); millions       Units  Number  5.941576
# 511  Gross Domestic Product (GDP); millions       Units  Number  6.523991
#
#                                             Variable_x  ... multifactor  \
# 0    Production-based CO2 productivity, GDP per uni...  ...    2.040453
# 1    Production-based CO2 productivity, GDP per uni...  ...    0.962618
# 2    Production-based CO2 productivity, GDP per uni...  ...    3.157764
# 3    Production-based CO2 productivity, GDP per uni...  ...    1.390201
# 4    Production-based CO2 productivity, GDP per uni...  ...    2.696690
# ..                                                 ...  ...         ...
# 507  Production-based CO2 productivity, GDP per uni...  ...   -9.279573
# 508  Production-based CO2 productivity, GDP per uni...  ...    6.739208
# 509  Production-based CO2 productivity, GDP per uni...  ...    6.462632
# 510  Production-based CO2 productivity, GDP per uni...  ...    2.493612
# 511  Production-based CO2 productivity, GDP per uni...  ...    2.900805
#
#      PowerCode_x                                         Variable_y POL  \
# 0          Units  Environmentally adjusted multifactor productiv...  CO
# 1          Units  Environmentally adjusted multifactor productiv...  CO
# 2          Units  Environmentally adjusted multifactor productiv...  CO
# 3          Units  Environmentally adjusted multifactor productiv...  CO
# 4          Units  Environmentally adjusted multifactor productiv...  CO
# ..           ...                                                ...  ..
# 507        Units  Environmentally adjusted multifactor productiv...  CO
# 508        Units  Environmentally adjusted multifactor productiv...  CO
# 509        Units  Environmentally adjusted multifactor productiv...  CO
# 510        Units  Environmentally adjusted multifactor productiv...  CO
# 511        Units  Environmentally adjusted multifactor productiv...  CO
#
#            Pollutant  VAR                  Variable Unit Code PowerCode_y  \
# 0    Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 1    Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 2    Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 3    Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 4    Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# ..               ...  ...                       ...       ...         ...
# 507  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 508  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 509  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 510  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 511  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
#
#         Value
# 0    6107.829
# 1    5387.306
# 2    5121.711
# 3    4985.813
# 4    4499.161
# ..        ...
# 507   173.525
# 508   155.535
# 509   171.268
# 510   166.276
# 511   159.241
#
# [512 rows x 21 columns]

# %%
df = test[['GDP','CO2 GDP','multifactor','Value']]
df
# Out:
#              GDP   CO2 GDP  multifactor     Value
# 0    574401.6402  2.013156     2.040453  6107.829
# 1    695179.4993  2.077365     0.962618  5387.306
# 2    722996.6281  2.120337     3.157764  5121.711
# 3    744585.0171  2.133708     1.390201  4985.813
# 4    774781.6857  2.226577     2.696690  4499.161
# ..           ...       ...          ...       ...
# 507   61222.6963  5.367111    -9.279573   173.525
# 508   62226.6379  5.052909     6.739208   155.535
# 509   65987.0750  5.725554     6.462632   171.268
# 510   68512.3701  5.941576     2.493612   166.276
# 511   70909.3307  6.523991     2.900805   159.241
#
# [512 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# %%
def standardNormalization(data):
    standardized = (data-data.mean())/data.std()
    return pd.Series(standardized)

# %%
x = df.GDP
z = df['CO2 GDP']
u = df.multifactor
x= standardNormalization(x)
u= standardNormalization(u)
z = standardNormalization(z)
d = {'GDP_STD': x, 'CO2 GDP_STD': z,'multifactor_STD':u,'emission':test.Value}
df = pd.DataFrame(data=d)
df
# Out:
#       GDP_STD  CO2 GDP_STD  multifactor_STD  emission
# 0   -0.248477    -1.292437         0.259973  6107.829
# 1   -0.199537    -1.255623        -0.189796  5387.306
# 2   -0.188265    -1.230984         0.726214  5121.711
# 3   -0.179518    -1.223318        -0.011370  4985.813
# 4   -0.167282    -1.170071         0.533813  4499.161
# ..        ...          ...              ...       ...
# 507 -0.456421     0.630568        -4.463746   173.525
# 508 -0.456014     0.450419         2.220710   155.535
# 509 -0.454490     0.836083         2.105298   171.268
# 510 -0.453467     0.959941         0.449071   166.276
# 511 -0.452496     1.293871         0.618988   159.241
#
# [512 rows x 4 columns]

# %%
df.corr().style.format('{:.2}').background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col2 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col3 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col0 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col3 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col0 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_3e734f82_4202_11ea_b335_7c2a31b3f780" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GDP_STD</th>        <th class="col_heading level0 col1" >CO2 GDP_STD</th>        <th class="col_heading level0 col2" >multifactor_STD</th>        <th class="col_heading level0 col3" >emission</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e734f82_4202_11ea_b335_7c2a31b3f780level0_row0" class="row_heading level0 row0" >GDP_STD</th>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col1" class="data row0 col1" >-0.17</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col2" class="data row0 col2" >-0.019</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row0_col3" class="data row0 col3" >0.88</td>
#             </tr>
#             <tr>
#                         <th id="T_3e734f82_4202_11ea_b335_7c2a31b3f780level0_row1" class="row_heading level0 row1" >CO2 GDP_STD</th>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col0" class="data row1 col0" >-0.17</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col2" class="data row1 col2" >-0.11</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row1_col3" class="data row1 col3" >-0.22</td>
#             </tr>
#             <tr>
#                         <th id="T_3e734f82_4202_11ea_b335_7c2a31b3f780level0_row2" class="row_heading level0 row2" >multifactor_STD</th>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col0" class="data row2 col0" >-0.019</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col1" class="data row2 col1" >-0.11</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row2_col3" class="data row2 col3" >0.00078</td>
#             </tr>
#             <tr>
#                         <th id="T_3e734f82_4202_11ea_b335_7c2a31b3f780level0_row3" class="row_heading level0 row3" >emission</th>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col0" class="data row3 col0" >0.88</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col1" class="data row3 col1" >-0.22</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col2" class="data row3 col2" >0.00078</td>
#                         <td id="T_3e734f82_4202_11ea_b335_7c2a31b3f780row3_col3" class="data row3 col3" >1.0</td>
#             </tr>
#     </tbody></table>

# %%
X = df[['GDP_STD','CO2 GDP_STD','multifactor_STD']]
y = df.emission
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                     Results: Ordinary least squares
# ========================================================================
# Model:                 OLS               Adj. R-squared:      0.782
# Dependent Variable:    emission          AIC:                 10336.2422
# Date:                  2020-01-28 21:13  BIC:                 10353.1955
# No. Observations:      512               Log-Likelihood:      -5164.1
# Df Model:              3                 F-statistic:         613.7
# Df Residuals:          508               Prob (F-statistic):  1.89e-168
# R-squared:             0.784             Scale:               3.4015e+07
# ------------------------------------------------------------------------
#                   Coef.    Std.Err.    t    P>|t|    [0.025     0.975]
# ------------------------------------------------------------------------
# const            3942.7700 257.7512 15.2968 0.0000  3436.3805  4449.1596
# GDP_STD         10898.1547 262.0106 41.5943 0.0000 10383.3969 11412.9124
# CO2 GDP_STD      -838.2857 263.6295 -3.1798 0.0016 -1356.2240  -320.3473
# multifactor_STD   127.4109 259.8475  0.4903 0.6241  -383.0971   637.9189
# ------------------------------------------------------------------------
# Omnibus:               471.513        Durbin-Watson:           0.534
# Prob(Omnibus):         0.000          Jarque-Bera (JB):        31419.460
# Skew:                  3.674          Prob(JB):                0.000
# Kurtosis:              40.667         Condition No.:           1
# ========================================================================
#
# """

# %%
sns.lmplot(x='GDP_STD',y='emission', ci= None, data=df, markers='.')
plt.gcf().suptitle('GDP vs emission ')
# Out:
# Text(0.5, 0.98, 'GDP vs emission ')

# %%
sns.lmplot(x='CO2 GDP_STD',y='emission', ci= None, data=df, markers='.')
plt.gcf().suptitle('CO2 GDP vs emission ')
# Out:
# Text(0.5, 0.98, 'CO2 GDP vs emission ')

# %%
sns.lmplot(x='multifactor_STD',y='emission', ci= None, data=df, markers='.')
plt.gcf().suptitle('multifactor vs emission ')
# Out:
# Text(0.5, 0.98, 'multifactor vs emission ')

# %% [markdown]
# # dettecting outliers

# %%
df.emission.describe()
# Out:
# count       512.000000
# mean       3942.770031
# std       12505.109672
# min          26.181000
# 25%         345.180750
# 50%         693.610500
# 75%        2954.745750
# max      108930.590000
# Name: emission, dtype: float64

# %%
test.loc[test.Value>50000]
# Out:
#            Country   YEA     Unit_x           GDP  PowerCode_x  \
# 414  United States  1995  US Dollar  1.021686e+07     Millions
# 415  United States  2000  US Dollar  1.262027e+07     Millions
# 416  United States  2001  US Dollar  1.274626e+07     Millions
# 417  United States  2002  US Dollar  1.296826e+07     Millions
# 418  United States  2003  US Dollar  1.333931e+07     Millions
# 419  United States  2004  US Dollar  1.384606e+07     Millions
# 420  United States  2005  US Dollar  1.433250e+07     Millions
# 421  United States  2006  US Dollar  1.474169e+07     Millions
# 422  United States  2007  US Dollar  1.501827e+07     Millions
# 423  United States  2008  US Dollar  1.499776e+07     Millions
# 424  United States  2009  US Dollar  1.461730e+07     Millions
# 425  United States  2010  US Dollar  1.499205e+07     Millions
# 426  United States  2011  US Dollar  1.522455e+07     Millions
# 427  United States  2012  US Dollar  1.556704e+07     Millions
# 428  United States  2013  US Dollar  1.585379e+07     Millions
#
#                                     Subject PowerCode_y  Unit_y   CO2 GDP  \
# 414  Gross Domestic Product (GDP); millions       Units  Number  2.013613
# 415  Gross Domestic Product (GDP); millions       Units  Number  2.202538
# 416  Gross Domestic Product (GDP); millions       Units  Number  2.235336
# 417  Gross Domestic Product (GDP); millions       Units  Number  2.338529
# 418  Gross Domestic Product (GDP); millions       Units  Number  2.377456
# 419  Gross Domestic Product (GDP); millions       Units  Number  2.433925
# 420  Gross Domestic Product (GDP); millions       Units  Number  2.513054
# 421  Gross Domestic Product (GDP); millions       Units  Number  2.631293
# 422  Gross Domestic Product (GDP); millions       Units  Number  2.640939
# 423  Gross Domestic Product (GDP); millions       Units  Number  2.720675
# 424  Gross Domestic Product (GDP); millions       Units  Number  2.854556
# 425  Gross Domestic Product (GDP); millions       Units  Number  2.801143
# 426  Gross Domestic Product (GDP); millions       Units  Number  2.968804
# 427  Gross Domestic Product (GDP); millions       Units  Number  3.174996
# 428  Gross Domestic Product (GDP); millions       Units  Number  3.146516
#
#                                             Variable_x  ... multifactor  \
# 414  Production-based CO2 productivity, GDP per uni...  ...    1.132900
# 415  Production-based CO2 productivity, GDP per uni...  ...    2.672647
# 416  Production-based CO2 productivity, GDP per uni...  ...    1.070859
# 417  Production-based CO2 productivity, GDP per uni...  ...    1.659841
# 418  Production-based CO2 productivity, GDP per uni...  ...    2.475850
# 419  Production-based CO2 productivity, GDP per uni...  ...    2.796275
# 420  Production-based CO2 productivity, GDP per uni...  ...    2.346243
# 421  Production-based CO2 productivity, GDP per uni...  ...    1.350672
# 422  Production-based CO2 productivity, GDP per uni...  ...    0.711365
# 423  Production-based CO2 productivity, GDP per uni...  ...    0.255427
# 424  Production-based CO2 productivity, GDP per uni...  ...   -0.097397
# 425  Production-based CO2 productivity, GDP per uni...  ...    2.008094
# 426  Production-based CO2 productivity, GDP per uni...  ...    0.993597
# 427  Production-based CO2 productivity, GDP per uni...  ...    1.482991
# 428  Production-based CO2 productivity, GDP per uni...  ...    1.017866
#
#      PowerCode_x                                         Variable_y POL  \
# 414        Units  Environmentally adjusted multifactor productiv...  CO
# 415        Units  Environmentally adjusted multifactor productiv...  CO
# 416        Units  Environmentally adjusted multifactor productiv...  CO
# 417        Units  Environmentally adjusted multifactor productiv...  CO
# 418        Units  Environmentally adjusted multifactor productiv...  CO
# 419        Units  Environmentally adjusted multifactor productiv...  CO
# 420        Units  Environmentally adjusted multifactor productiv...  CO
# 421        Units  Environmentally adjusted multifactor productiv...  CO
# 422        Units  Environmentally adjusted multifactor productiv...  CO
# 423        Units  Environmentally adjusted multifactor productiv...  CO
# 424        Units  Environmentally adjusted multifactor productiv...  CO
# 425        Units  Environmentally adjusted multifactor productiv...  CO
# 426        Units  Environmentally adjusted multifactor productiv...  CO
# 427        Units  Environmentally adjusted multifactor productiv...  CO
# 428        Units  Environmentally adjusted multifactor productiv...  CO
#
#            Pollutant  VAR                  Variable Unit Code PowerCode_y  \
# 414  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 415  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 416  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 417  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 418  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 419  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 420  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 421  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 422  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 423  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 424  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 425  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 426  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 427  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
# 428  Carbon Monoxide  TOT  Total man-made emissions     TONNE   Thousands
#
#           Value
# 414  108930.590
# 415   92913.610
# 416   89375.868
# 417   79816.663
# 418   77602.959
# 419   75384.361
# 420   73161.908
# 421   70704.493
# 422   68247.078
# 423   61195.150
# 424   54933.143
# 425   55857.149
# 426   55393.766
# 427   53609.261
# 428   51824.755
#
# [15 rows x 21 columns]

# %% [markdown]
# ##  All the outliers are all from the U.S.A

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
y_train_predicted = regr.predict(X_train)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.18085638 -0.13864041  0.00938598]
# Mean squared error: 0.19
# Coefficient of determination: 0.23

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.2348896428091345

# %%
print("------ TRAIN DATA ------")
print("MSE:",metrics.mean_squared_error(y_train, y_train_predicted))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_train, y_train_predicted)))
print("MAE:",metrics.mean_absolute_error(y_train, y_train_predicted))
# Out:
# ------ TRAIN DATA ------
# MSE: 0.19165643467850388
# RMSE: 0.43778583197552645
# MAE: 0.4143717954909691

# %%
print("------ TEST DATA ------")
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# ------ TEST DATA ------
# MSE: 0.19039689678913252
# RMSE: 0.43634492868501695
# MAE: 0.41713209652542144

# %%
fitted_emission = regr.predict(X) # returns ndarray
df['FittedEmission']=pd.Series(fitted_emission)
res=df['emission']-df['FittedEmission']
df['Res']=pd.Series(res)

# %%
df.head(20)
# Out:
#      GDP_STD  CO2 GDP_STD  multifactor_STD  emission  FittedEmission  \
# 0  -0.248477    -1.292437         0.259973  6107.829     2441.320626
# 1  -0.199537    -1.255623        -0.189796  5387.306     2893.478489
# 2  -0.188265    -1.230984         0.726214  5121.711     3016.066070
# 3  -0.179518    -1.223318        -0.011370  4985.813     3076.808753
# 4  -0.167282    -1.170071         0.533813  4499.161     3177.823451
# 5  -0.157222    -1.177874        -0.048118  4593.240     3267.325449
# 6  -0.148168    -1.157357        -0.109246  3973.013     3341.872148
# 7  -0.135364    -1.127013         0.092371  3944.595     3454.802313
# 8  -0.122712    -1.115460        -0.039824  3382.893     3569.772915
# 9  -0.115768    -1.101126        -0.467438  3226.740     3616.758625
# 10 -0.108212    -1.097085        -0.178424  3158.219     3698.267060
# 11 -0.099026    -1.036946        -0.448807  2994.791     3739.787267
# 12 -0.084117    -0.976160         0.248001  2939.839     3866.743117
# 13 -0.073729    -0.936139         0.035640  2902.792     3936.351175
# 14 -0.358997     0.351011         0.350171   728.242      163.992341
# 15 -0.357448     0.199372        -0.267404   708.173      269.350950
# 16 -0.355404     0.185764        -0.086952   683.222      304.872277
# 17 -0.354219     0.025037        -0.556984   691.091      417.375394
# 18 -0.350745     0.048104         0.469612   680.747      466.004785
# 19 -0.347817     0.078227         0.171208   616.616      465.208031
#
#             Res
# 0   3666.508374
# 1   2493.827511
# 2   2105.644930
# 3   1909.004247
# 4   1321.337549
# 5   1325.914551
# 6    631.140852
# 7    489.792687
# 8   -186.879915
# 9   -390.018625
# 10  -540.048060
# 11  -744.996267
# 12  -926.904117
# 13 -1033.559175
# 14   564.249659
# 15   438.822050
# 16   378.349723
# 17   273.715606
# 18   214.742215
# 19   151.407969

# %%
df_class = test[['Value']]

# %% [markdown]
# ## classification

# %% [markdown]
# ### make new varibale of highe & low emission

# %%
print(test.GDP.median())
print(test['CO2 GDP'].median())
print(test.multifactor.median())
print(test.Value.median())
# Out:
# 322167.2097
# 4.0701745
# 1.5300835
# 693.6105

# %%
df_class['GDP_Level'] =test['GDP']
df_class['CO2_Level'] = test['CO2 GDP']
df_class['multifactor_Level'] = test['multifactor']

df_class['EmissionLevel'] = np.where(test['Value']>693.6105, 1, 0)
df_class
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\boork\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\boork\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\boork\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#         Value    GDP_Level  CO2_Level  multifactor_Level  EmissionLevel
# 0    6107.829  574401.6402   2.013156           2.040453              1
# 1    5387.306  695179.4993   2.077365           0.962618              1
# 2    5121.711  722996.6281   2.120337           3.157764              1
# 3    4985.813  744585.0171   2.133708           1.390201              1
# 4    4499.161  774781.6857   2.226577           2.696690              1
# ..        ...          ...        ...                ...            ...
# 507   173.525   61222.6963   5.367111          -9.279573              0
# 508   155.535   62226.6379   5.052909           6.739208              0
# 509   171.268   65987.0750   5.725554           6.462632              0
# 510   166.276   68512.3701   5.941576           2.493612              0
# 511   159.241   70909.3307   6.523991           2.900805              0
#
# [512 rows x 5 columns]

# %%
x = df_class.GDP_Level
z = df_class['CO2_Level']
u = df_class.multifactor_Level
x= standardNormalization(x)
u= standardNormalization(u)
z = standardNormalization(z)
d = {'GDP_STD': x, 'CO2 GDP_STD': z,'multifactor_STD':u,'emission':df_class.EmissionLevel}
df_class = pd.DataFrame(data=d)
df_class
# Out:
#       GDP_STD  CO2 GDP_STD  multifactor_STD  emission
# 0   -0.248477    -1.292437         0.259973         1
# 1   -0.199537    -1.255623        -0.189796         1
# 2   -0.188265    -1.230984         0.726214         1
# 3   -0.179518    -1.223318        -0.011370         1
# 4   -0.167282    -1.170071         0.533813         1
# ..        ...          ...              ...       ...
# 507 -0.456421     0.630568        -4.463746         0
# 508 -0.456014     0.450419         2.220710         0
# 509 -0.454490     0.836083         2.105298         0
# 510 -0.453467     0.959941         0.449071         0
# 511 -0.452496     1.293871         0.618988         0
#
# [512 rows x 4 columns]

# %%
X=df_class[['GDP_STD','CO2 GDP_STD', 'multifactor_STD']] #dataframe
y=df_class['emission'] #series
X
# Out:
#       GDP_STD  CO2 GDP_STD  multifactor_STD
# 0   -0.248477    -1.292437         0.259973
# 1   -0.199537    -1.255623        -0.189796
# 2   -0.188265    -1.230984         0.726214
# 3   -0.179518    -1.223318        -0.011370
# 4   -0.167282    -1.170071         0.533813
# ..        ...          ...              ...
# 507 -0.456421     0.630568        -4.463746
# 508 -0.456014     0.450419         2.220710
# 509 -0.454490     0.836083         2.105298
# 510 -0.453467     0.959941         0.449071
# 511 -0.452496     1.293871         0.618988
#
# [512 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
# run the model
from sklearn.linear_model import LogisticRegression
#1 create the model
logmodel = LogisticRegression()
#2 train it on the trainind data
logmodel.fit(X_train,y_train)
#3 get prediction on the testing data
y_prob=logmodel.predict_proba(X_test)
y_pred = logmodel.predict(X_test)
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# create a new dataframe with predicted probabilities and class labels.
prob=pd.DataFrame(y_prob ,columns=['py_0', 'py_1'])
prob1 = pd.DataFrame(prob ,columns=['py_1'])
prob0 = pd.DataFrame(prob ,columns=['py_0'])
y_pred = pd.DataFrame(y_pred ,columns=['y_pred'])
ytest = pd.DataFrame(y_test,columns=['emission'])
ytest.reset_index(drop=True,inplace=True) #reset the ind

# %%
result = pd.concat([ytest,prob1,prob0,y_pred],axis=1)
result.head(20)
# Out:
#     emission      py_1          py_0  y_pred
# 0          1  0.880003  1.199973e-01       1
# 1          0  0.029506  9.704935e-01       0
# 2          1  0.740474  2.595259e-01       1
# 3          0  0.155359  8.446406e-01       0
# 4          1  0.574445  4.255549e-01       1
# 5          1  0.523825  4.761752e-01       1
# 6          0  0.114772  8.852280e-01       0
# 7          1  0.995662  4.338173e-03       1
# 8          0  0.523578  4.764218e-01       1
# 9          1  1.000000  7.105427e-15       1
# 10         0  0.031044  9.689556e-01       0
# 11         0  0.405516  5.944839e-01       0
# 12         0  0.050441  9.495595e-01       0
# 13         0  0.207757  7.922431e-01       0
# 14         0  0.073512  9.264880e-01       0
# 15         0  0.242609  7.573908e-01       0
# 16         1  0.607698  3.923022e-01       1
# 17         1  0.725549  2.744513e-01       1
# 18         1  0.511993  4.880071e-01       1
# 19         1  0.927000  7.300040e-02       1

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[66  3]
#  [ 9 76]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        69
#            1       0.96      0.89      0.93        85
#
#     accuracy                           0.92       154
#    macro avg       0.92      0.93      0.92       154
# weighted avg       0.93      0.92      0.92       154
