# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt  # visualization
import seaborn as sns # visualization
# %matplotlib inline
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns        module    <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>

# %%
GDP_CO2_df = pd.read_csv("GDP_CO2.csv")
productGDP_df = pd.read_csv("gross_domestic_product.csv")
multifactor_PG_df = pd.read_csv("multifactor_PG.csv")
watter_df = pd.read_csv("WATER_TREAT_05122019095241312.csv")

# %% [markdown]
# # Wastewater treatment
# ## This indicator presents sewage treatment connection rates, i.e. the percentage of the population connected to a wastewater treatment plant. “Connected” means actually connected to a wastewater treatment plant through a public sewage network. It does not take into account independent private facilities, used where public systems are not economic.This indicator is measured in percentage.

# %%
watter_df
# Out:
#             VAR                                           Variable  COU  \
# 0     TOTPUBSEW  Total public sewerage (% of resident populatio...  AUS
# 1     TOTPUBSEW  Total public sewerage (% of resident populatio...  AUS
# 2     TOTPUBSEW  Total public sewerage (% of resident populatio...  AUS
# 3     TOTPUBSEW  Total public sewerage (% of resident populatio...  AUS
# 4     TOTPUBSEW  Total public sewerage (% of resident populatio...  AUS
# ...         ...                                                ...  ...
# 2831   PUBTOTTR  Public total treatment (connected to a wastewa...  AUS
# 2832   PUBTOTTR  Public total treatment (connected to a wastewa...  AUS
# 2833   PUBTOTTR  Public total treatment (connected to a wastewa...  AUS
# 2834   PUBTOTTR  Public total treatment (connected to a wastewa...  AUS
# 2835   PUBTOTTR  Public total treatment (connected to a wastewa...  AUS
#
#         Country   YEA  Year Unit Code        Unit  PowerCode Code PowerCode  \
# 0     Australia  2010  2010        PC  Percentage               0     Units
# 1     Australia  2011  2011        PC  Percentage               0     Units
# 2     Australia  2012  2012        PC  Percentage               0     Units
# 3     Australia  2013  2013        PC  Percentage               0     Units
# 4     Australia  2014  2014        PC  Percentage               0     Units
# ...         ...   ...   ...       ...         ...             ...       ...
# 2831  Australia  2013  2013        PC  Percentage               0     Units
# 2832  Australia  2014  2014        PC  Percentage               0     Units
# 2833  Australia  2015  2015        PC  Percentage               0     Units
# 2834  Australia  2016  2016        PC  Percentage               0     Units
# 2835  Australia  2017  2017        PC  Percentage               0     Units
#
#       Reference Period Code  Reference Period  Value Flag Codes Flags
# 0                       NaN               NaN  93.18        NaN   NaN
# 1                       NaN               NaN  93.54        NaN   NaN
# 2                       NaN               NaN  94.10        NaN   NaN
# 3                       NaN               NaN  94.08        NaN   NaN
# 4                       NaN               NaN  92.57        NaN   NaN
# ...                     ...               ...    ...        ...   ...
# 2831                    NaN               NaN  94.08        NaN   NaN
# 2832                    NaN               NaN  92.57        NaN   NaN
# 2833                    NaN               NaN  92.38        NaN   NaN
# 2834                    NaN               NaN  92.48        NaN   NaN
# 2835                    NaN               NaN  92.69        NaN   NaN
#
# [2836 rows x 15 columns]

# %%
watter =watter_df.loc[(watter_df.VAR == 'NOPUBSEWIND')]
watter.drop(['Year', 'COU','Reference Period Code','Reference Period','Flag Codes','Flags','PowerCode Code','PowerCode'], axis=1,inplace = True) #not needed columns.
watter
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#               VAR                                           Variable  \
# 2075  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2076  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2077  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2078  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2079  NOPUBSEWIND  Not connected to public sewerage or independen...
# ...           ...                                                ...
# 2765  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2766  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2767  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2768  NOPUBSEWIND  Not connected to public sewerage or independen...
# 2769  NOPUBSEWIND  Not connected to public sewerage or independen...
#
#         Country   YEA Unit Code        Unit      Value
# 2075    Austria  1990        PC  Percentage  28.000000
# 2076    Austria  2000        PC  Percentage  14.599998
# 2077    Austria  2010        PC  Percentage   6.099998
# 2078    Austria  2012        PC  Percentage   5.500000
# 2079    Austria  2014        PC  Percentage   5.032387
# ...         ...   ...       ...         ...        ...
# 2765  Lithuania  2013        PC  Percentage  25.500000
# 2766  Lithuania  2014        PC  Percentage  24.550003
# 2767  Lithuania  2015        PC  Percentage  23.300003
# 2768  Lithuania  2016        PC  Percentage  22.491295
# 2769  Lithuania  2017        PC  Percentage  26.099998
#
# [275 rows x 7 columns]

# %%
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'G7'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'G20'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD - Europe'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD - Total'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD America'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'World'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'ASEAN'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Latin America and Caribbean'].index , inplace = True)
multifactor_PG_df.drop(multifactor_PG_df.loc[multifactor_PG_df['Country'] == 'Middle East and North Africa'].index , inplace = True)
multifactor = multifactor_PG_df.loc[multifactor_PG_df['VAR'] == 'EAMFP_EAMFPG']
multifactor.shape
# Out:
# (744, 15)

# %%
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'G7'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'G20'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD - Europe'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD - Total'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD America'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
GDP_CO2_df.drop(GDP_CO2_df.loc[GDP_CO2_df['Country'] == 'World'].index , inplace = True)
GDP_CO2 =GDP_CO2_df.loc[(GDP_CO2_df.VAR == 'CO2_PBPROD')]
GDP_CO2.shape
# Out:
# (2674, 15)

# %%
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'G7'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'Euro area (19 countries)'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'European Union (28 countries)'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD - Total'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'Eastern Europe, Caucasus and Central Asia'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'G20'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD - Europe'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD America'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'OECD Asia Oceania'].index , inplace = True)
productGDP_df.drop(productGDP_df.loc[productGDP_df['Country'] == 'World'].index , inplace = True)
productGDP=productGDP_df.loc[(productGDP_df['SUBJECT'] == 'T_GDP')&(productGDP_df.Unit == 'US Dollar')& (productGDP_df.MEASURE =='VPVOB')]
productGDP.shape
# Out:
# (1813, 17)

# %%
CO2_col = GDP_CO2[['Country','YEA','PowerCode','Unit','Value','Variable',]]
productGDP_col = productGDP[['Country','TIME','Unit','Value','PowerCode','Subject']]
multifactor_col = multifactor[['Country','YEA','Unit','Value','PowerCode','Variable']]

# %%
productGDP_col.rename(columns ={'TIME' : 'YEA'}, inplace=True )
GDPandCO2 = pd.merge(productGDP_col, CO2_col, on=['Country','YEA'], how='inner')
test = pd.merge(GDPandCO2, multifactor_col, on=['Country','YEA'], how='inner')
test.rename(columns ={'Value_x' : 'GDP'}, inplace=True )
test.rename(columns ={'Value_y' : 'CO2 GDP'}, inplace=True )
test.rename(columns ={'Value' : 'multifactor'}, inplace=True )
test
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#        Country   YEA     Unit_x          GDP PowerCode_x  \
# 0    Australia  1995  US Dollar  574401.6402    Millions
# 1    Australia  2000  US Dollar  695179.4993    Millions
# 2    Australia  2001  US Dollar  722996.6281    Millions
# 3    Australia  2002  US Dollar  744585.0171    Millions
# 4    Australia  2003  US Dollar  774781.6857    Millions
# ..         ...   ...        ...          ...         ...
# 622  Lithuania  2009  US Dollar   61222.6963    Millions
# 623  Lithuania  2010  US Dollar   62226.6379    Millions
# 624  Lithuania  2011  US Dollar   65987.0750    Millions
# 625  Lithuania  2012  US Dollar   68512.3701    Millions
# 626  Lithuania  2013  US Dollar   70909.3307    Millions
#
#                                     Subject PowerCode_y  Unit_y   CO2 GDP  \
# 0    Gross Domestic Product (GDP); millions       Units  Number  2.013156
# 1    Gross Domestic Product (GDP); millions       Units  Number  2.077365
# 2    Gross Domestic Product (GDP); millions       Units  Number  2.120337
# 3    Gross Domestic Product (GDP); millions       Units  Number  2.133708
# 4    Gross Domestic Product (GDP); millions       Units  Number  2.226577
# ..                                      ...         ...     ...       ...
# 622  Gross Domestic Product (GDP); millions       Units  Number  5.367111
# 623  Gross Domestic Product (GDP); millions       Units  Number  5.052909
# 624  Gross Domestic Product (GDP); millions       Units  Number  5.725554
# 625  Gross Domestic Product (GDP); millions       Units  Number  5.941576
# 626  Gross Domestic Product (GDP); millions       Units  Number  6.523991
#
#                                             Variable_x               Unit  \
# 0    Production-based CO2 productivity, GDP per uni...  Percentage points
# 1    Production-based CO2 productivity, GDP per uni...  Percentage points
# 2    Production-based CO2 productivity, GDP per uni...  Percentage points
# 3    Production-based CO2 productivity, GDP per uni...  Percentage points
# 4    Production-based CO2 productivity, GDP per uni...  Percentage points
# ..                                                 ...                ...
# 622  Production-based CO2 productivity, GDP per uni...  Percentage points
# 623  Production-based CO2 productivity, GDP per uni...  Percentage points
# 624  Production-based CO2 productivity, GDP per uni...  Percentage points
# 625  Production-based CO2 productivity, GDP per uni...  Percentage points
# 626  Production-based CO2 productivity, GDP per uni...  Percentage points
#
#      multifactor PowerCode                                         Variable_y
# 0       2.040453     Units  Environmentally adjusted multifactor productiv...
# 1       0.962618     Units  Environmentally adjusted multifactor productiv...
# 2       3.157764     Units  Environmentally adjusted multifactor productiv...
# 3       1.390201     Units  Environmentally adjusted multifactor productiv...
# 4       2.696690     Units  Environmentally adjusted multifactor productiv...
# ..           ...       ...                                                ...
# 622    -9.279573     Units  Environmentally adjusted multifactor productiv...
# 623     6.739208     Units  Environmentally adjusted multifactor productiv...
# 624     6.462632     Units  Environmentally adjusted multifactor productiv...
# 625     2.493612     Units  Environmentally adjusted multifactor productiv...
# 626     2.900805     Units  Environmentally adjusted multifactor productiv...
#
# [627 rows x 14 columns]

# %%
test = pd.merge(test, watter, on=['Country','YEA'], how='inner')
test
# Out:
#        Country   YEA     Unit_x          GDP PowerCode_x  \
# 0      Austria  2000  US Dollar  301652.6082    Millions
# 1      Austria  2010  US Dollar  351313.6961    Millions
# 2      Austria  2012  US Dollar  364042.2481    Millions
# 3      Belgium  2000  US Dollar  371636.0925    Millions
# 4      Belgium  2005  US Dollar  406583.9113    Millions
# ..         ...   ...        ...          ...         ...
# 140  Lithuania  2005  US Dollar   58692.8858    Millions
# 141  Lithuania  2010  US Dollar   62226.6379    Millions
# 142  Lithuania  2011  US Dollar   65987.0750    Millions
# 143  Lithuania  2012  US Dollar   68512.3701    Millions
# 144  Lithuania  2013  US Dollar   70909.3307    Millions
#
#                                     Subject PowerCode_y  Unit_y   CO2 GDP  \
# 0    Gross Domestic Product (GDP); millions       Units  Number  4.879529
# 1    Gross Domestic Product (GDP); millions       Units  Number  5.123355
# 2    Gross Domestic Product (GDP); millions       Units  Number  5.697505
# 3    Gross Domestic Product (GDP); millions       Units  Number  3.259823
# 4    Gross Domestic Product (GDP); millions       Units  Number  3.775959
# ..                                      ...         ...     ...       ...
# 140  Gross Domestic Product (GDP); millions       Units  Number  4.716557
# 141  Gross Domestic Product (GDP); millions       Units  Number  5.052909
# 142  Gross Domestic Product (GDP); millions       Units  Number  5.725554
# 143  Gross Domestic Product (GDP); millions       Units  Number  5.941576
# 144  Gross Domestic Product (GDP); millions       Units  Number  6.523991
#
#                                             Variable_x             Unit_x  \
# 0    Production-based CO2 productivity, GDP per uni...  Percentage points
# 1    Production-based CO2 productivity, GDP per uni...  Percentage points
# 2    Production-based CO2 productivity, GDP per uni...  Percentage points
# 3    Production-based CO2 productivity, GDP per uni...  Percentage points
# 4    Production-based CO2 productivity, GDP per uni...  Percentage points
# ..                                                 ...                ...
# 140  Production-based CO2 productivity, GDP per uni...  Percentage points
# 141  Production-based CO2 productivity, GDP per uni...  Percentage points
# 142  Production-based CO2 productivity, GDP per uni...  Percentage points
# 143  Production-based CO2 productivity, GDP per uni...  Percentage points
# 144  Production-based CO2 productivity, GDP per uni...  Percentage points
#
#      multifactor PowerCode                                         Variable_y  \
# 0       2.256607     Units  Environmentally adjusted multifactor productiv...
# 1       0.978398     Units  Environmentally adjusted multifactor productiv...
# 2       0.381858     Units  Environmentally adjusted multifactor productiv...
# 3       1.711185     Units  Environmentally adjusted multifactor productiv...
# 4       1.509310     Units  Environmentally adjusted multifactor productiv...
# ..           ...       ...                                                ...
# 140     1.041857     Units  Environmentally adjusted multifactor productiv...
# 141     6.739208     Units  Environmentally adjusted multifactor productiv...
# 142     6.462632     Units  Environmentally adjusted multifactor productiv...
# 143     2.493612     Units  Environmentally adjusted multifactor productiv...
# 144     2.900805     Units  Environmentally adjusted multifactor productiv...
#
#              VAR                                           Variable Unit Code  \
# 0    NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 1    NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 2    NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 3    NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 4    NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# ..           ...                                                ...       ...
# 140  NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 141  NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 142  NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 143  NOPUBSEWIND  Not connected to public sewerage or independen...        PC
# 144  NOPUBSEWIND  Not connected to public sewerage or independen...        PC
#
#          Unit_y      Value
# 0    Percentage  14.599998
# 1    Percentage   6.099998
# 2    Percentage   5.500000
# 3    Percentage  20.856102
# 4    Percentage  15.995399
# ..          ...        ...
# 140  Percentage  31.410004
# 141  Percentage  27.699997
# 142  Percentage  27.000000
# 143  Percentage  25.879997
# 144  Percentage  25.500000
#
# [145 rows x 19 columns]

# %%
df = test[['GDP','CO2 GDP','multifactor','Value']]
df
# Out:
#              GDP   CO2 GDP  multifactor      Value
# 0    301652.6082  4.879529     2.256607  14.599998
# 1    351313.6961  5.123355     0.978398   6.099998
# 2    364042.2481  5.697505     0.381858   5.500000
# 3    371636.0925  3.259823     1.711185  20.856102
# 4    406583.9113  3.775959     1.509310  15.995399
# ..           ...       ...          ...        ...
# 140   58692.8858  4.716557     1.041857  31.410004
# 141   62226.6379  5.052909     6.739208  27.699997
# 142   65987.0750  5.725554     6.462632  27.000000
# 143   68512.3701  5.941576     2.493612  25.879997
# 144   70909.3307  6.523991     2.900805  25.500000
#
# [145 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
def standardNormalization(data):
    standardized = (data-data.mean())/data.std()
    return pd.Series(standardized)

# %%
x = df.GDP
z = df['CO2 GDP']
u = df.multifactor
x= standardNormalization(x)
u= standardNormalization(u)
z = standardNormalization(z)
d = {'GDP_STD': x, 'CO2 GDP_STD': z,'multifactor_STD':u,'watter':test.Value}
df = pd.DataFrame(data=d)
df
# Out:
#       GDP_STD  CO2 GDP_STD  multifactor_STD     watter
# 0   -0.299916     0.148942         0.243462  14.599998
# 1   -0.273331     0.277399        -0.305265   6.099998
# 2   -0.266517     0.579882        -0.561355   5.500000
# 3   -0.262452    -0.704379         0.009316  20.856102
# 4   -0.243743    -0.432459        -0.077348  15.995399
# ..        ...          ...              ...        ...
# 140 -0.429982     0.063082        -0.278022  31.410004
# 141 -0.428090     0.240285         2.167810  27.699997
# 142 -0.426077     0.594659         2.049078  27.000000
# 143 -0.424725     0.708468         0.345206  25.879997
# 144 -0.423442     1.015305         0.520011  25.500000
#
# [145 rows x 4 columns]

# %%
df.corr().style.format('{:.2}').background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col2 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col3 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col2 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col0 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_0008538c_4203_11ea_83e6_7c2a31b3f780" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GDP_STD</th>        <th class="col_heading level0 col1" >CO2 GDP_STD</th>        <th class="col_heading level0 col2" >multifactor_STD</th>        <th class="col_heading level0 col3" >watter</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0008538c_4203_11ea_83e6_7c2a31b3f780level0_row0" class="row_heading level0 row0" >GDP_STD</th>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col1" class="data row0 col1" >-0.11</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col2" class="data row0 col2" >-0.0083</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row0_col3" class="data row0 col3" >0.032</td>
#             </tr>
#             <tr>
#                         <th id="T_0008538c_4203_11ea_83e6_7c2a31b3f780level0_row1" class="row_heading level0 row1" >CO2 GDP_STD</th>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col0" class="data row1 col0" >-0.11</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col2" class="data row1 col2" >-0.09</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row1_col3" class="data row1 col3" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_0008538c_4203_11ea_83e6_7c2a31b3f780level0_row2" class="row_heading level0 row2" >multifactor_STD</th>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col0" class="data row2 col0" >-0.0083</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col1" class="data row2 col1" >-0.09</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row2_col3" class="data row2 col3" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_0008538c_4203_11ea_83e6_7c2a31b3f780level0_row3" class="row_heading level0 row3" >watter</th>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col0" class="data row3 col0" >0.032</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col1" class="data row3 col1" >-0.27</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col2" class="data row3 col2" >0.14</td>
#                         <td id="T_0008538c_4203_11ea_83e6_7c2a31b3f780row3_col3" class="data row3 col3" >1.0</td>
#             </tr>
#     </tbody></table>

# %%
X = df[['GDP_STD','CO2 GDP_STD','multifactor_STD']]
y = df.watter
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\boork\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.066
# Dependent Variable: watter           AIC:                1140.7087
# Date:               2020-01-28 21:18 BIC:                1152.6157
# No. Observations:   145              Log-Likelihood:     -566.35
# Df Model:           3                F-statistic:        4.408
# Df Residuals:       141              Prob (F-statistic): 0.00537
# R-squared:          0.086            Scale:              148.69
# ------------------------------------------------------------------
#                     Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------
# const              18.4512   1.0127 18.2206 0.0000 16.4492 20.4531
# GDP_STD             0.0642   1.0225  0.0627 0.9501 -1.9572  2.0855
# CO2 GDP_STD        -3.2216   1.0266 -3.1381 0.0021 -5.2511 -1.1921
# multifactor_STD     1.5304   1.0204  1.4998 0.1359 -0.4869  3.5478
# ------------------------------------------------------------------
# Omnibus:              20.939        Durbin-Watson:           0.580
# Prob(Omnibus):        0.000         Jarque-Bera (JB):        6.252
# Skew:                 0.143         Prob(JB):                0.044
# Kurtosis:             2.024         Condition No.:           1
# ==================================================================
#
# """

# %%
sns.lmplot(x='GDP_STD',y='watter', ci= None, data=df, markers='.')
plt.gcf().suptitle('GDP vs Not connected to public sewerage  ')
# Out:
# Text(0.5, 0.98, 'GDP vs Not connected to public sewerage  ')

# %%
sns.lmplot(x='CO2 GDP_STD',y='watter', ci= None, data=df, markers='.')
plt.gcf().suptitle('CO2 GDP vs Not connected to public sewerage ')
# Out:
# Text(0.5, 0.98, 'CO2 GDP vs Not connected to public sewerage ')

# %%
sns.lmplot(x='multifactor_STD',y='watter', ci= None, data=df, markers='.')
plt.gcf().suptitle('Not connected to public sewerage  ')
# Out:
# Text(0.5, 0.98, 'Not connected to public sewerage  ')

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
y_train_predicted = regr.predict(X_train)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.29126756 -3.89205477  1.2876535 ]
# Mean squared error: 136.23
# Coefficient of determination: 0.06

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.08154182633231388

# %%
from sklearn import metrics

print("------ TRAIN DATA ------")
print("MSE:",metrics.mean_squared_error(y_train, y_train_predicted))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_train, y_train_predicted)))
print("MAE:",metrics.mean_absolute_error(y_train, y_train_predicted))
# Out:
# ------ TRAIN DATA ------
# MSE: 149.18650569538488
# RMSE: 12.214192797536187
# MAE: 10.32859178196113

# %%
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 136.22754350287505
# RMSE: 11.671655559639989
# MAE: 10.070095083727514

# %%
fitted_Gross = regr.predict(X) # returns ndarray
df['FittedWatter']=pd.Series(fitted_Gross)
res=df['watter']-df['FittedWatter']
df['Res']=pd.Series(res)
df.head(20)
